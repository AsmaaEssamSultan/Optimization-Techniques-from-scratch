# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

# %% [markdown]
# #### Generate data

# %%
X = np.linspace(0,20,30).reshape(30,1)
Y = (-1*X+2).reshape(30,1)

# %% [markdown]
# #### Plot data points

# %%
plt.scatter(X,Y)
plt.grid()
plt.show()

# %% [markdown]
# ## Adam

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def Adam(X, Y, alpha, Gamma, Beta, Epsilon, Iterations):
    theta_0 , theta_1 = 0 , 0
    Vt0 = 0
    Vt1 = 0
    Mt0 = 0
    Mt1 = 0
    m = X.size
    J_L = []
    H_L = []
    theta_0L = [0]
    theta_1L = [0]
    for i in range(Iterations):
        h = theta_0 + theta_1 * X
        H_L.append(h)
    
        J = (1/(2*m))*sum((h - Y)**2)
        J_L.extend(J)

        dtheta_0 = (1/m)*sum(h - Y)
        dtheta_1 = (1/m)*sum((h - Y)* X)
        
        Mt0 = Gamma * Mt0 + (1-Gamma)*dtheta_0
        Mt1 = Gamma * Mt1 + (1-Gamma)*dtheta_1
        
        Vt0 = Beta*Vt0 + (1-Beta)*dtheta_0**2
        Vt1 = Beta*Vt1 + (1-Beta)*dtheta_1**2
        
        dtheta = np.array([dtheta_0,
                          dtheta_1])
        if np.linalg.norm(dtheta) < 0.1:
            break
        
        if i > 1 and abs(J_L[-2]- J_L[-1]) < 0.001:
            break
    
        if i < Iterations-1:
            theta_0 = theta_0 - (alpha/(np.sqrt(Vt0)+Epsilon))*Mt0
            theta_0L.extend(theta_0)
            theta_1 = theta_1 - (alpha/(np.sqrt(Vt1)+Epsilon))*Mt1
            theta_1L.extend(theta_1)
            
    return theta_0L, theta_1L, J_L, H_L, theta_0, theta_1

# %%
alpha = 0.01
Epsilon = 1e-8
Beta = 0.8
Gamma = 0.6
Iterations = 100000
theta_0L, theta_1L, J_L, H_L, theta_0, theta_1 = Adam(X, Y, alpha, Gamma, Beta, Epsilon, Iterations)

# %%
print(theta_0)
print(theta_1)
# Out:
# [1.57648504]
# [-0.96689141]

# %%
r2_score(Y,theta_0+ theta_1*X)
# Out:
# 0.998664062453922

# %%
iterations = [i for i in range(len(J_L))]
plt.figure()
plt.plot(iterations ,J_L, c = 'r')
plt.title("Loss Function vs Iteration")
plt.xlabel("Iteration")
plt.ylabel("Loss function")
plt.grid()
plt.show()

# %%
plt.figure()
plt.plot(theta_0L ,J_L, c = 'r')
plt.title("Loss Function vs Theta0")
plt.xlabel("Theta_0")
plt.ylabel("Loss function")
plt.grid()
plt.show()

# %%
plt.figure()
plt.plot(theta_1L ,J_L, c = 'r')
plt.title("Loss Function vs Theta1")
plt.xlabel("Theta_1")
plt.ylabel("Loss function")
plt.grid()
plt.show()

# %%
plt.figure()
plt.plot(X , theta_0L + theta_1L*X)
plt.title("Plot all lines calaclated during traning")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid()
plt.show()

# %%
plt.figure()
plt.scatter(X,Y)
plt.plot(X , theta_0+ theta_1*X, c='r')
plt.title("Plot best line")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid()
plt.show()
